# %% [markdown]
# ## Permutation test

# %%
import json 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from hypyp import stats 
'''
Comparing inter-connectivity to random signal
'''

f = open('results_plv.json')

# returns JSON object as 
# a dictionary
results = json.load(f)
  
# Iterating through the json
# list
fp1 = []
sf1 = []
fp2 = []
sf2 = []
reunion = []

all_stages = [fp1, sf1, fp2, sf2, reunion]
for part, data in results.items():
    for stage, bands in data.items():
        stage = stage[1]
        all_stages[int(stage)-1].append(bands)

fp1_theta = []
fp1_alpha = []
sf1_theta = []
sf1_alpha = []
fp2_theta = []
fp2_alpha = []
sf2_theta = []
sf2_alpha = []
ru_theta = []
ru_alpha = []
for part1, part3, part4, part5 in zip(fp1, fp2, sf2, reunion):
    fp1_theta.append(np.mean(part1['theta']))
    fp1_alpha.append(np.mean(part1['alpha']))

for part2 in sf1:
    sf1_theta.append(np.mean(part2['theta']))
    sf1_alpha.append(np.mean(part2['alpha']))

for part3 in fp2:
    fp2_theta.append(np.mean(part3['theta']))
    fp2_alpha.append(np.mean(part3['alpha']))

for part4 in sf2:
    sf2_theta.append(np.mean(part4['theta']))
    sf2_alpha.append(np.mean(part4['alpha']))

for part5 in reunion:
    ru_theta.append(np.mean(part5['theta']))
    ru_alpha.append(np.mean(part5['alpha']))


data_theta = [np.vstack(fp1_theta), np.vstack(sf1_theta), np.vstack(fp2_theta), np.vstack(sf2_theta), np.vstack(ru_theta)] # , np.vstack(fp2_theta), np.vstack(sf2_theta), np.vstack(ru_theta)
data_alpha = [np.vstack(fp1_alpha), np.vstack(sf1_alpha), np.vstack(fp2_alpha), np.vstack(sf2_alpha), np.vstack(ru_alpha)]

# Closing file
f.close()

# %%
permutation_test = stats.statscondCluster(data = data_theta,
                                          freqs_mean = np.arange(3, 7),
                                          ch_con_freq = None,
                                          tail = 0,
                                          n_permutations = 5000,
                                          alpha = 0.05)
# Out:
# Using a threshold of 2.372450
# stat_fun(H1): min=0.086142 max=8.891121
# Running initial clustering …
# Found 14 clusters
# /home/agata/Desktop/thesis/.venv/lib/python3.10/site-packages/hypyp/stats.py:337: RuntimeWarning: Ignoring argument "tail", performing 1-tailed F-test
#   F_obs, clusters, cluster_p_values, H0 = permutation_cluster_test(data,
#   0%|          | Permuting : 0/4999 [00:00<?,       ?it/s]

# %%
permutation_test_alpha = stats.statscondCluster(data = data_alpha,
                                          freqs_mean = np.arange(6, 12),
                                          ch_con_freq = None,
                                          tail = 0,
                                          n_permutations = 10000,
                                          alpha = 0.05)
# Out:
# Using a threshold of 2.372450
# stat_fun(H1): min=0.184099 max=7.736805
# Running initial clustering …
# Found 17 clusters
# /home/agata/Desktop/thesis/.venv/lib/python3.10/site-packages/hypyp/stats.py:337: RuntimeWarning: Ignoring argument "tail", performing 1-tailed F-test
#   F_obs, clusters, cluster_p_values, H0 = permutation_cluster_test(data,
#   0%|          | Permuting : 0/9999 [00:00<?,       ?it/s]

# %%
import json 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from hypyp import stats 
'''
Comparing inter-connectivity to random signal
'''

f = open('cross_frequency_results.json')

# returns JSON object as 
# a dictionary
results = json.load(f)
  
# Iterating through the json
# list
fp1 = []
sf1 = []
fp2 = []
sf2 = []
reunion = []

all_stages = [fp1, sf1, fp2, sf2, reunion]
for part, data in results.items():
    for stage, bands in data.items():
        stage = stage[1]
        all_stages[int(stage)-1].append(bands)

fp1_theta = []
fp1_alpha = []
sf1_theta = []
sf1_alpha = []
fp2_theta = []
fp2_alpha = []
sf2_theta = []
sf2_alpha = []
ru_theta = []
ru_alpha = []
import json 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from hypyp import stats 
'''
Comparing inter-connectivity to random signal
'''

f = open('cross_frequency_results.json')

# returns JSON object as 
# a dictionary
results = json.load(f)
  
# Iterating through the json
# list
fp1 = []
sf1 = []
fp2 = []
sf2 = []
reunion = []

all_stages = [fp1, sf1, fp2, sf2, reunion]
for part, data in results.items():
    for stage, bands in data.items():
        stage = stage[1]
        all_stages[int(stage)-1].append(bands)

fp1_theta = []
fp1_alpha = []
sf1_theta = []
sf1_alpha = []
fp2_theta = []
fp2_alpha = []
sf2_theta = []
sf2_alpha = []
ru_theta = []
ru_alpha = []
for part1, part3, part4, part5 in zip(fp1, fp2, sf2, reunion):
    fp1_theta.append(np.mean(part1['theta']))
    fp1_alpha.append(np.mean(part1['alpha']))

for part2 in sf1:
    sf1_theta.append(np.mean(part2['theta']))
    sf1_alpha.append(np.mean(part2['alpha']))

for part3 in fp2:
    fp2_theta.append(np.mean(part3['theta']))
    fp2_alpha.append(np.mean(part3['alpha']))

for part4 in sf2:
    sf2_theta.append(np.mean(part4['theta']))
    sf2_alpha.append(np.mean(part4['alpha']))

for part5 in reunion:
    ru_theta.append(np.mean(part5['theta']))
    ru_alpha.append(np.mean(part5['alpha']))


data_theta_plot = [fp1_theta, sf1_theta, fp2_theta, sf2_theta, ru_theta] 

fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
ax.set_ylim(0.1, 0.22)
ax.set_title('Theta Band')
ax.set_ylabel('Values')
 # x-axis labels
ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])
 
# Creating plot
bp = ax.boxplot(data_theta_plot)


# show plot
plt.show()

f.close()
# Out:
# /tmp/ipykernel_16548/3436415052.py:110: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])

# %%
data_alpha_plot = [fp1_alpha, sf1_alpha, fp2_alpha, sf2_alpha, ru_alpha] 

fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
ax.set_ylim(0.1, 0.2)
ax.set_title('Alpha Band')
ax.set_ylabel('Values')
 # x-axis labels
ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])
 
# Creating plot
bp = ax.boxplot(data_alpha_plot)
# Out:
# /tmp/ipykernel_16548/3826664082.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])

# %% [markdown]
# ## Non-cross-frequency PLVs

# %%
import json 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from hypyp import stats 
import matplotlib.pyplot as plt
'''
Comparing inter-connectivity to random signal
'''

f = open('results_plv.json')

# returns JSON object as 
# a dictionary
results = json.load(f)
  
# Iterating through the json
# list
fp1 = []
sf1 = []
fp2 = []
sf2 = []
reunion = []

all_stages = [fp1, sf1, fp2, sf2, reunion]
for part, data in results.items():
    for stage, bands in data.items():
        stage = stage[1]
        all_stages[int(stage)-1].append(bands)

fp1_theta = []
fp1_alpha = []
sf1_theta = []
sf1_alpha = []
fp2_theta = []
fp2_alpha = []
sf2_theta = []
sf2_alpha = []
ru_theta = []
ru_alpha = []
for part1, part3, part4, part5 in zip(fp1, fp2, sf2, reunion):
    fp1_theta.append(np.mean(part1['theta']))
    fp1_alpha.append(np.mean(part1['alpha']))

for part2 in sf1:
    sf1_theta.append(np.mean(part2['theta']))
    sf1_alpha.append(np.mean(part2['alpha']))

for part3 in fp2:
    fp2_theta.append(np.mean(part3['theta']))
    fp2_alpha.append(np.mean(part3['alpha']))

for part4 in sf2:
    sf2_theta.append(np.mean(part4['theta']))
    sf2_alpha.append(np.mean(part4['alpha']))

for part5 in reunion:
    ru_theta.append(np.mean(part5['theta']))
    ru_alpha.append(np.mean(part5['alpha']))

data = [fp1_theta, sf1_theta, fp2_theta, sf2_theta, ru_theta]

fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
# ax.set_ylim(0.14, 0.23)
ax.set_title('Theta Band')
ax.set_ylabel('Values')
 # x-axis labels
ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])
 
# Creating plot
bp = ax.boxplot(data)


# show plot
plt.show()

# Closing file
f.close()
# Out:
# /tmp/ipykernel_16548/2188966823.py:71: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])

# %%
data = [fp1_alpha, sf1_alpha, fp2_alpha, sf2_alpha, ru_alpha]

fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
# ax.set_ylim(0.14, 0.23)
ax.set_title('Alpha Band')
ax.set_ylabel('Values')
 # x-axis labels
ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])
 
# Creating plot
bp = ax.boxplot(data)


# show plot
plt.show()

# Closing file
f.close()
# Out:
# /tmp/ipykernel_16548/2048620341.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])

# %% [markdown]
# ## PLI

# %%
import json 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from hypyp import stats 
'''
Comparing inter-connectivity to random signal
'''

f = open('results_wpli.json')

# returns JSON object as 
# a dictionary
results = json.load(f)
  
# Iterating through the json
# list
fp1 = []
sf1 = []
fp2 = []
sf2 = []
reunion = []

all_stages = [fp1, sf1, fp2, sf2, reunion]
for part, data in results.items():
    for stage, bands in data.items():
        stage = stage[1]
        all_stages[int(stage)-1].append(bands)

fp1_theta = []
fp1_alpha = []
sf1_theta = []
sf1_alpha = []
fp2_theta = []
fp2_alpha = []
sf2_theta = []
sf2_alpha = []
ru_theta = []
ru_alpha = []
for part1, part3, part4, part5 in zip(fp1, fp2, sf2, reunion):
    fp1_theta.append(np.mean(part1['theta']))
    fp1_alpha.append(np.mean(part1['alpha']))

for part2 in sf1:
    sf1_theta.append(np.mean(part2['theta']))
    sf1_alpha.append(np.mean(part2['alpha']))

for part3 in fp2:
    fp2_theta.append(np.mean(part3['theta']))
    fp2_alpha.append(np.mean(part3['alpha']))

for part4 in sf2:
    sf2_theta.append(np.mean(part4['theta']))
    sf2_alpha.append(np.mean(part4['alpha']))

for part5 in reunion:
    ru_theta.append(np.mean(part5['theta']))
    ru_alpha.append(np.mean(part5['alpha']))

data_theta_pli = [fp1_theta, sf1_theta, fp2_theta, sf2_theta, ru_theta]
data_theta_pli = [fp1_alpha, sf1_alpha, fp2_alpha, sf2_alpha, ru_alpha]

fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
# ax.set_ylim(0.14, 0.23)
ax.set_title('Alpha Band')
ax.set_ylabel('Values')
 # x-axis labels
ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])
 
# Creating plot
bp = ax.boxplot(data)


# show plot
plt.show()

# Closing file
f.close()
# Out:
# /tmp/ipykernel_16548/1323036303.py:70: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])

# %%
f = open('results_pli.json')

# returns JSON object as 
# a dictionary
results = json.load(f)

# Iterating through the json
# list
fp1 = []
sf1 = []
fp2 = []
sf2 = []
reunion = []

all_stages = [fp1, sf1, fp2, sf2, reunion]
for part, data in results.items():
    for stage, bands in data.items():
        stage = stage[1]
        all_stages[int(stage)-1].append(bands)

fp1_theta = []
fp1_alpha = []
sf1_theta = []
sf1_alpha = []
fp2_theta = []
fp2_alpha = []
sf2_theta = []
sf2_alpha = []
ru_theta = []
ru_alpha = []
for part1 in fp1:
    fp1_theta.append(np.mean(part1['theta']))
    fp1_alpha.append(np.mean(part1['alpha']))

for part2 in sf1:
    sf1_theta.append(np.mean(part2['theta']))
    sf1_alpha.append(np.mean(part2['alpha']))

for part3 in fp2:
    fp2_theta.append(np.mean(part3['theta']))
    fp2_alpha.append(np.mean(part3['alpha']))

for part4 in sf2:
    sf2_theta.append(np.mean(part4['theta']))
    sf2_alpha.append(np.mean(part4['alpha']))

for part5 in reunion:
    ru_theta.append(np.mean(part5['theta']))
    ru_alpha.append(np.mean(part5['alpha']))

data_theta_pli = [fp1_theta, sf1_theta, fp2_theta, sf2_theta, ru_theta]
data_alpha_pli = [fp1_alpha, sf1_alpha, fp2_alpha, sf2_alpha, ru_alpha]

fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
# ax.set_ylim(0.14, 0.23)
ax.set_title('Theta Band')
ax.set_ylabel('Values')
 # x-axis labels
ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])
 
# Creating plot
bp = ax.boxplot(data_theta_pli)


# show plot
plt.show()

# Closing file
f.close()
# Out:
# /tmp/ipykernel_16548/1812428136.py:62: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])

# %%
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
# ax.set_ylim(0.14, 0.23)
ax.set_title('Alpha Band')
ax.set_ylabel('Values')
 # x-axis labels
ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])
 
# Creating plot
bp = ax.boxplot(data_alpha_pli)


# show plot
plt.show()

# Closing file
f.close()
# Out:
# /tmp/ipykernel_16548/1458148064.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['free play 1', 'still face 1', 'free play 2', 'still face 2', 'reunion'])
